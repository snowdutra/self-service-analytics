# %%
import pandas as pd

# %%
serie = pd.Series([6, 7, 10, 8, 8.5])

# %%
print(serie.mean())

# %%
alunos = {"nome": ["João", "Maria", "Antonio"],
          "notas": [10, 10, 9.5]}

# %%
df= pd.DataFrame(alunos)

# %%
print(df)

# %%
# !curl -O https://raw.githubusercontent.com/esensato/ssa-2026-01/main/entrada.csv

# %%
df = pd.read_csv("entrada.csv")
df.head()

# %%
df.dropna()
